# %% [markdown]
# <a href="https://colab.research.google.com/github/andryowiniciusac-creator/Python-e-Astronomia/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 21/04/2026

# %%
import numpy as np

brilho_estrelas = np.array([1.2, 0.5, 2.8, 1.1])
brilho_corrigido = brilho_estrelas * 2  # Aplica em todas de uma vez
print(brilho_corrigido)
# O exemplo acima foi gerado 100% por IA para estudar a sintaxe
# Out:
# [2.4 1.  5.6 2.2]
