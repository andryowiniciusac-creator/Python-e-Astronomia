# %% [markdown]
# <a href="https://colab.research.google.com/github/andryowiniciusac-creator/Python-e-Astronomia/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 21/04/2026

# %%
import matplotlib.pyplot as plt

tempo = [1, 2, 3, 4, 5]
brilho = [10, 9.8, 10.1, 9.7, 10]

plt.plot(tempo, brilho)
plt.ylabel('Brilho da Estrela')
plt.xlabel('Dias')
plt.show()
# O exemplo acima foi gerado 100% por IA para estudar a sintaxe
