# %% [markdown]
# <a href="https://colab.research.google.com/github/andryowiniciusac-creator/Python-e-Astronomia/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 21/04/2026

# %%
import pandas as pd

dados = pd.DataFrame({'estrela': ['Sol', 'Sirius', 'Vega'], 'temp': [5778, 9940, 9602]})
quentes = dados[dados['temp'] > 9000]
print(quentes)
# Out:
#   estrela  temp
# 1  Sirius  9940
# 2    Vega  9602
